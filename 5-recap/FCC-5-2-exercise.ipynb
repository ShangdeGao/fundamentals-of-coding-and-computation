# %% [markdown]
# # Module 1 recap: exercises

# %% [markdown]
# ## Find errors

# %% [markdown]
# Find the errors in the code and write down your solutions.

# %% [markdown]
# ### Exercise 1.

# %% [markdown]
# I want to find a restaurant and order some food, but the code is not working...

# %%
def find_restaurant():
    print("Let's go to Dragonfly for dinner.")
    oder_food()

find_restaurant()

def oder_food():
    print("Let's order Dominos!")

# %% [markdown]
# #### Solution

# %%
# write down the solution here

# %% [markdown]
# ### Exercise 2.

# %% [markdown]
# I want to decide what to eat today, but the code is not working...

# %%
today = "friday"

if today = "monday":
    print("order sushi")
else:
    if today = "thursday":
        print("order pizza")
    else:
        print("cook at home")

# %% [markdown]
# #### Solution

# %%
# write down the solution here

# %% [markdown]
# ### Exercise 3.

# %% [markdown]
# I want to give a new name to my puppy, but the code does not print the correct name...

# %%
puppy_name = "Fluffy"

def change_puppy_name():
    puppy_name = "Lazzy"

change_puppy_name()
print(puppy_name)

# %% [markdown]
# #### Solution

# %%
# write down the solution here

# %% [markdown]
# ### Exercise 4.

# %% [markdown]
# I want to compute the total of a list of numbers, but the code is not working...

# %%
numbers = ['1', '2', '3', '4', '5']
total = 0

for i in numbers:
    total = total + i

total

# %% [markdown]
# #### Solution

# %%
# write down the solution here
